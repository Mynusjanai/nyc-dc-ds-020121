# %%
import pandas as pd
import numpy as np 

pd.set_option('display.max_columns', 300)

# %% [markdown]
# ## Step 1: Read in hold out data, scalers, and best model

# %%
df = pd.read_csv('movie_holdout_data.csv', index_col=0)
print(df.shape)
df.head()
# Out:
# (625, 28)
#       color       director_name  num_critic_for_reviews  duration  \
# 4551  Color            Eli Roth                   285.0     100.0
# 126   Color      Lana Wachowski                   275.0     138.0
# 2251  Color       Todd Phillips                   110.0     108.0
# 601   Color  Jonathan Liebesman                   355.0     116.0
# 397   Color       George Miller                   206.0     108.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 4551                      0.0                   389.0     Richard Burgi
# 126                       0.0                    30.0  Daniel Bernhardt
# 2251                    480.0                   579.0   Sarah Silverman
# 601                     473.0                   464.0       Jim Parrack
# 397                     750.0                   971.0      Hugh Jackman
#
#       actor_1_facebook_likes                                 genres  \
# 4551                   640.0                       Adventure|Horror
# 126                    234.0                          Action|Sci-Fi
# 2251                   970.0                                 Comedy
# 601                    833.0                          Action|Sci-Fi
# 397                  49000.0  Animation|Comedy|Family|Music|Romance
#
#         actor_1_name             movie_title  num_voted_users  \
# 4551    Daryl Sabara      The Green Inferno             21468
# 126    Steve Bastoni    The Matrix Reloaded            421818
# 2251       Jon Heder  School for Scoundrels             26100
# 601      Noel Fisher     Battle Los Angeles            154955
# 397   Robin Williams             Happy Feet            132501
#
#       cast_total_facebook_likes     actor_3_name  facenumber_in_poster  \
# 4551                       2082  Magda Apanowicz                   0.0
# 126                         534  Helmut Bakaitis                   0.0
# 2251                       4374  Jacinda Barrett                   1.0
# 601                        4001  Ramon Rodriguez                   0.0
# 397                       70996  Elizabeth Daily                   0.0
#
#                                           plot_keywords  \
# 4551    activist|amazon|color in title|rain|rain forest
# 126   car motorcycle chase|one against many|oracle|p...
# 2251  paintball|paintball gun|pepper spray|tennis|wh...
# 601      alien|extraterrestrial|invasion|marine|mission
# 397           dance|emperor penguin|friend|penguin|song
#
#                                         movie_imdb_link  num_user_for_reviews  \
# 4551  http://www.imdb.com/title/tt2403021/?ref_=fn_t...                 164.0
# 126   http://www.imdb.com/title/tt0234215/?ref_=fn_t...                2789.0
# 2251  http://www.imdb.com/title/tt0462519/?ref_=fn_t...                  97.0
# 601   http://www.imdb.com/title/tt1217613/?ref_=fn_t...                 800.0
# 397   http://www.imdb.com/title/tt0366548/?ref_=fn_t...                 548.0
#
#      language country content_rating       budget  title_year  \
# 4551  English     USA              R    6000000.0      2013.0
# 126   English     USA              R  150000000.0      2003.0
# 2251  English     USA          PG-13   20000000.0      2006.0
# 601   English     USA          PG-13   70000000.0      2011.0
# 397   English     USA             PG  100000000.0      2006.0
#
#       actor_2_facebook_likes  imdb_score  aspect_ratio  movie_facebook_likes  \
# 4551                   550.0         5.4          2.35                 12000
# 126                    198.0         7.2          2.35                     0
# 2251                   931.0         5.9          2.35                   484
# 601                    697.0         5.8          2.35                 25000
# 397                  20000.0         6.5          2.35                     0
#
#             gross
# 4551    7186670.0
# 126   281492479.0
# 2251   17803796.0
# 601    83552429.0
# 397   197992827.0

# %%
import pickle

# %%
infile = open("model.pickle",'rb')
model = pickle.load(infile)
infile.close()

# %%
print(model.intercept_)
print(len(model.coef_))
# Out:
# -27897408.26477901
# 17

# %%
infile = open("other_info.pickle",'rb')
other_info = pickle.load(infile)
infile.close()

# %%
other_info
# Out:
# [{'G': 57937616.7, 'PG': 53613525.3, 'PG-13': 52682723.4, 'R': 25223942.9},
#  2187.8671468587436,
#  827.0320384461354,
#  109.22168867547019,
#  Index(['duration', 'director_facebook_likes', 'actor_3_facebook_likes',
#         'actor_1_facebook_likes', 'cast_total_facebook_likes', 'budget',
#         'actor_2_facebook_likes', 'yrs_old', 'superstar', 'content_rating_PG',
#         'content_rating_PG-13', 'content_rating_R', 'color_Color', 'PG_budget',
#         'PG13_budget', 'R_budget', 'superstar_budget'],
#        dtype='object')]

# %%
df.head()
# Out:
#       color       director_name  num_critic_for_reviews  duration  \
# 4551  Color            Eli Roth                   285.0     100.0
# 126   Color      Lana Wachowski                   275.0     138.0
# 2251  Color       Todd Phillips                   110.0     108.0
# 601   Color  Jonathan Liebesman                   355.0     116.0
# 397   Color       George Miller                   206.0     108.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 4551                      0.0                   389.0     Richard Burgi
# 126                       0.0                    30.0  Daniel Bernhardt
# 2251                    480.0                   579.0   Sarah Silverman
# 601                     473.0                   464.0       Jim Parrack
# 397                     750.0                   971.0      Hugh Jackman
#
#       actor_1_facebook_likes                                 genres  \
# 4551                   640.0                       Adventure|Horror
# 126                    234.0                          Action|Sci-Fi
# 2251                   970.0                                 Comedy
# 601                    833.0                          Action|Sci-Fi
# 397                  49000.0  Animation|Comedy|Family|Music|Romance
#
#         actor_1_name             movie_title  num_voted_users  \
# 4551    Daryl Sabara      The Green Inferno             21468
# 126    Steve Bastoni    The Matrix Reloaded            421818
# 2251       Jon Heder  School for Scoundrels             26100
# 601      Noel Fisher     Battle Los Angeles            154955
# 397   Robin Williams             Happy Feet            132501
#
#       cast_total_facebook_likes     actor_3_name  facenumber_in_poster  \
# 4551                       2082  Magda Apanowicz                   0.0
# 126                         534  Helmut Bakaitis                   0.0
# 2251                       4374  Jacinda Barrett                   1.0
# 601                        4001  Ramon Rodriguez                   0.0
# 397                       70996  Elizabeth Daily                   0.0
#
#                                           plot_keywords  \
# 4551    activist|amazon|color in title|rain|rain forest
# 126   car motorcycle chase|one against many|oracle|p...
# 2251  paintball|paintball gun|pepper spray|tennis|wh...
# 601      alien|extraterrestrial|invasion|marine|mission
# 397           dance|emperor penguin|friend|penguin|song
#
#                                         movie_imdb_link  num_user_for_reviews  \
# 4551  http://www.imdb.com/title/tt2403021/?ref_=fn_t...                 164.0
# 126   http://www.imdb.com/title/tt0234215/?ref_=fn_t...                2789.0
# 2251  http://www.imdb.com/title/tt0462519/?ref_=fn_t...                  97.0
# 601   http://www.imdb.com/title/tt1217613/?ref_=fn_t...                 800.0
# 397   http://www.imdb.com/title/tt0366548/?ref_=fn_t...                 548.0
#
#      language country content_rating       budget  title_year  \
# 4551  English     USA              R    6000000.0      2013.0
# 126   English     USA              R  150000000.0      2003.0
# 2251  English     USA          PG-13   20000000.0      2006.0
# 601   English     USA          PG-13   70000000.0      2011.0
# 397   English     USA             PG  100000000.0      2006.0
#
#       actor_2_facebook_likes  imdb_score  aspect_ratio  movie_facebook_likes  \
# 4551                   550.0         5.4          2.35                 12000
# 126                    198.0         7.2          2.35                     0
# 2251                   931.0         5.9          2.35                   484
# 601                    697.0         5.8          2.35                 25000
# 397                  20000.0         6.5          2.35                     0
#
#             gross
# 4551    7186670.0
# 126   281492479.0
# 2251   17803796.0
# 601    83552429.0
# 397   197992827.0

# %%
df.isna().mean()
# Out:
# color                        0.0000
# director_name                0.0000
# num_critic_for_reviews       0.0000
# duration                     0.0000
# director_facebook_likes      0.0000
# actor_3_facebook_likes       0.0016
# actor_2_name                 0.0000
# actor_1_facebook_likes       0.0000
# genres                       0.0000
# actor_1_name                 0.0000
# movie_title                  0.0000
# num_voted_users              0.0000
# cast_total_facebook_likes    0.0000
# actor_3_name                 0.0016
# facenumber_in_poster         0.0048
# plot_keywords                0.0048
# movie_imdb_link              0.0000
# num_user_for_reviews         0.0000
# language                     0.0000
# country                      0.0000
# content_rating               0.0000
# budget                       0.0464
# title_year                   0.0000
# actor_2_facebook_likes       0.0000
# imdb_score                   0.0000
# aspect_ratio                 0.0144
# movie_facebook_likes         0.0000
# gross                        0.0000
# dtype: float64

# %% [markdown]
# ## Step 2: Feature Engineering for holdout set

# %% [markdown]
# Remember we have to perform the same transformations on our holdout data (feature engineering, extreme values, and scaling) that we performed on the original data.

# %%
df['actor_1_facebook_likes']= np.where(df['actor_1_facebook_likes'] >200000, 200000, df['actor_1_facebook_likes'])
df['actor_2_facebook_likes']= np.where(df['actor_2_facebook_likes'] >100000, 100000, df['actor_2_facebook_likes'])
df['cast_total_facebook_likes']= np.where(df['cast_total_facebook_likes'] >300000, 300000, df['cast_total_facebook_likes'])

# %%
df['title_year']= pd.to_datetime(df['title_year'], format='%Y')
df['yrs_old']= 2016-  pd.DatetimeIndex(df['title_year']).year

# %%
other_info[0]
# Out:
# {'G': 57937616.7, 'PG': 53613525.3, 'PG-13': 52682723.4, 'R': 25223942.9}

# %%
budget_ratings = other_info[0]

# %%
df['budget'].fillna(df['content_rating'].map(budget_ratings), inplace=True)

# %%
act_3_mean =other_info[2]

# %%
df['actor_3_facebook_likes'].fillna(act_3_mean, inplace=True)

# %%
df['superstar'] = np.where(df['actor_1_facebook_likes']>=25000, 1, 0)

# %%
df = pd.get_dummies(df, columns=['content_rating', 'color'], drop_first=True)

# %%
df.head()
# Out:
#            director_name  num_critic_for_reviews  duration  \
# 4551            Eli Roth                   285.0     100.0
# 126       Lana Wachowski                   275.0     138.0
# 2251       Todd Phillips                   110.0     108.0
# 601   Jonathan Liebesman                   355.0     116.0
# 397        George Miller                   206.0     108.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 4551                      0.0                   389.0     Richard Burgi
# 126                       0.0                    30.0  Daniel Bernhardt
# 2251                    480.0                   579.0   Sarah Silverman
# 601                     473.0                   464.0       Jim Parrack
# 397                     750.0                   971.0      Hugh Jackman
#
#       actor_1_facebook_likes                                 genres  \
# 4551                   640.0                       Adventure|Horror
# 126                    234.0                          Action|Sci-Fi
# 2251                   970.0                                 Comedy
# 601                    833.0                          Action|Sci-Fi
# 397                  49000.0  Animation|Comedy|Family|Music|Romance
#
#         actor_1_name             movie_title  num_voted_users  \
# 4551    Daryl Sabara      The Green Inferno             21468
# 126    Steve Bastoni    The Matrix Reloaded            421818
# 2251       Jon Heder  School for Scoundrels             26100
# 601      Noel Fisher     Battle Los Angeles            154955
# 397   Robin Williams             Happy Feet            132501
#
#       cast_total_facebook_likes     actor_3_name  facenumber_in_poster  \
# 4551                       2082  Magda Apanowicz                   0.0
# 126                         534  Helmut Bakaitis                   0.0
# 2251                       4374  Jacinda Barrett                   1.0
# 601                        4001  Ramon Rodriguez                   0.0
# 397                       70996  Elizabeth Daily                   0.0
#
#                                           plot_keywords  \
# 4551    activist|amazon|color in title|rain|rain forest
# 126   car motorcycle chase|one against many|oracle|p...
# 2251  paintball|paintball gun|pepper spray|tennis|wh...
# 601      alien|extraterrestrial|invasion|marine|mission
# 397           dance|emperor penguin|friend|penguin|song
#
#                                         movie_imdb_link  num_user_for_reviews  \
# 4551  http://www.imdb.com/title/tt2403021/?ref_=fn_t...                 164.0
# 126   http://www.imdb.com/title/tt0234215/?ref_=fn_t...                2789.0
# 2251  http://www.imdb.com/title/tt0462519/?ref_=fn_t...                  97.0
# 601   http://www.imdb.com/title/tt1217613/?ref_=fn_t...                 800.0
# 397   http://www.imdb.com/title/tt0366548/?ref_=fn_t...                 548.0
#
#      language country       budget  title_year  actor_2_facebook_likes  \
# 4551  English     USA    6000000.0      2013.0                   550.0
# 126   English     USA  150000000.0      2003.0                   198.0
# 2251  English     USA   20000000.0      2006.0                   931.0
# 601   English     USA   70000000.0      2011.0                   697.0
# 397   English     USA  100000000.0      2006.0                 20000.0
#
#       imdb_score  aspect_ratio  movie_facebook_likes        gross  superstar  \
# 4551         5.4          2.35                 12000    7186670.0          0
# 126          7.2          2.35                     0  281492479.0          0
# 2251         5.9          2.35                   484   17803796.0          0
# 601          5.8          2.35                 25000   83552429.0          0
# 397          6.5          2.35                     0  197992827.0          1
#
#       content_rating_PG  content_rating_PG-13  content_rating_R  color_Color
# 4551                  0                     0                 1            1
# 126                   0                     0                 1            1
# 2251                  0                     1                 0            1
# 601                   0                     1                 0            1
# 397                   1                     0                 0            1

# %%
# your code here
df['budget^2']= df['budget']*df['budget']
df['actor_1_facebook_likes^2'] = df['actor_1_facebook_likes'] * df['actor_1_facebook_likes']   
df['actor_2_facebook_likes^2'] = df['actor_2_facebook_likes'] * df['actor_2_facebook_likes'] 
df['actor_3_facebook_likes^2'] = df['actor_3_facebook_likes'] * df['actor_3_facebook_likes'] 
df['cast_total_facebook_likes^2'] = df['cast_total_facebook_likes'] * df['cast_total_facebook_likes']

# %%
# your code here

df['cast_fb_budget'] = df['cast_total_facebook_likes'] *df['budget']
df['PG_budget'] = df['content_rating_PG'] *df['budget']
df['PG13_budget'] = df['content_rating_PG-13'] *df['budget']
df['R_budget'] = df['content_rating_R'] *df['budget']
df['superstar_budget'] = df['superstar'] *df['budget']
df['cast_fb_budget^2']= df['cast_total_facebook_likes'] *df['budget^2']

# %% [markdown]
# ## Step 3: Predict the holdout set

# %%
final_columns = list(other_info[4])

# %%
len(final_columns)
# Out:
# 17

# %%
final_answers = model.predict(df[final_columns])

# %%
final_answers
# Out:
# array([ 6.85602129e+06,  1.22252595e+08,  3.52322029e+07,  8.16161464e+07,
#         1.43648758e+08,  3.34278363e+07,  3.23075776e+07,  4.47920000e+07,
#         6.69858988e+07,  8.06978488e+07,  5.85293186e+07,  3.29428646e+07,
#         2.33917167e+06,  3.85302930e+08,  6.33153793e+06,  3.36083224e+07,
#         6.99822160e+07,  3.98800480e+07,  1.43217122e+08,  3.63910398e+07,
#         2.11372105e+08,  3.21398315e+07,  3.48517087e+07,  2.68582672e+07,
#         1.00046342e+08,  1.84145761e+08,  8.20721298e+07,  2.18905589e+07,
#         1.33716051e+08,  7.53594190e+06,  1.93335608e+07,  3.99480739e+07,
#         1.82503225e+08,  4.40992563e+07,  3.21317493e+07,  3.21796140e+07,
#         7.46441328e+07,  6.39604973e+07,  1.24844685e+08,  5.32538214e+07,
#         1.12564656e+07,  9.12760139e+07,  1.35926680e+07,  1.91992102e+07,
#         3.16276965e+07,  5.19506594e+07,  1.40842044e+07,  6.95683810e+07,
#         2.63166927e+07,  8.11999078e+07,  1.20544180e+07,  2.01402507e+07,
#         1.09542883e+08,  6.30862922e+06,  4.37783665e+07,  8.33208706e+07,
#         7.13075314e+07,  3.12844569e+07,  5.11854738e+07,  6.96089528e+07,
#         1.49386920e+07,  4.21986707e+07,  1.99530123e+07,  5.54299483e+07,
#         2.31799147e+07,  5.92810570e+07,  3.97501999e+07,  5.42180189e+07,
#         2.81829816e+07,  2.84499180e+07,  8.70710609e+06,  2.99878511e+07,
#         8.18658672e+07,  1.57744501e+07,  9.58508338e+07,  3.98797674e+07,
#         3.61286912e+07,  2.23890149e+07,  6.22868247e+07,  8.81840352e+07,
#         1.32740614e+08,  9.30902901e+07,  1.73173128e+08,  3.19757791e+07,
#         6.76422302e+07,  7.84661396e+06,  3.47512624e+06,  7.00967101e+06,
#         3.85866110e+07,  8.02015186e+07,  1.31156643e+07,  3.62959671e+06,
#         2.96026651e+07,  7.15238332e+07,  9.55111440e+07,  2.83146454e+07,
#         2.66620073e+07,  7.26600986e+07,  4.94867009e+07,  2.43141225e+07,
#         4.64167364e+07,  3.38208080e+07,  1.73832106e+08,  2.57304270e+07,
#         4.87508877e+07,  4.50584268e+07,  1.66770266e+08,  1.69519217e+08,
#         4.35415223e+07,  8.64204831e+06,  1.02252417e+08,  4.06195627e+07,
#         3.05298044e+07,  2.14192004e+07,  1.13145469e+08,  5.86424057e+07,
#         3.33651093e+07,  1.31875762e+08,  2.44279548e+07,  6.39507894e+07,
#         1.51404155e+08,  4.55695293e+07,  3.25215197e+07,  1.75342932e+07,
#         3.77970462e+07,  4.95763508e+07,  7.32482847e+07,  4.82393043e+07,
#         3.10213320e+07,  3.58705072e+07,  8.87139797e+07,  3.40757657e+07,
#         3.94265088e+07,  1.31586143e+07,  3.53462133e+07,  1.47191137e+06,
#         4.49999870e+07,  5.15058008e+07,  1.60043272e+07,  5.75956932e+07,
#         4.00976451e+07,  4.03993618e+07,  8.48411748e+07,  2.71353424e+07,
#         6.23441843e+07,  7.09336573e+07,  2.70689756e+07,  2.73868317e+07,
#         1.33529990e+08,  6.72882874e+07,  3.17676064e+07,  5.56089929e+07,
#         1.31467455e+07,  1.31083660e+08,  2.86268506e+07,  9.52885287e+07,
#         7.53109072e+07,  1.84085081e+07,  1.88905935e+07,  1.09517208e+07,
#         1.61344181e+07,  2.50021901e+07,  3.20636210e+07,  2.92490009e+07,
#         2.35424062e+07])

# %% [markdown]
# ## Step 4: Export your predictions

# %%
Final = pd.DataFrame(final_answers)

# %%
final_answers.to_csv('housing_preds_your_name.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-417575eeffff> in <module>
# ----> 1 final_answers.to_csv('housing_preds_your_name.csv')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_csv'
